# %% [markdown]
# # Iteration - the while loop

# %% [markdown]
# ## Exercise
# * Create a variables and assign a number values to it
# * Write a *while* loop which adds 1 to the variable in each iteration until the variable is larger than 10

# %% [markdown]
# ## Exercise
#
# *   Use a *while* loop to program a 'countdown' from 10 to 0

# %% [markdown]
# ## Exercise
# * Write a *while* loop in which a number between 100 and 200 is incrementally increased by 1 .
# * In this loop print the number only if it can be divided by 3. Use the *continue* statement.

# %% [markdown]
# ## Exercise
# * Use a while loop which converts temperature values between 20 and 40 degrees Celcius to Farenheit

# %% [markdown]
# ## Exercise
# * Use a *while* loop to print numbers between 1 and 20.
# * Use the *break* statement to interrupt the loop in case the values is larger than 14.

# %% [markdown]
# ## Exercise
# * Use a *while* loop which prints numbers between 7 and 14.
# * Use the *else* statement to print a 'end of loop' message

# %% [markdown]
# ## Exercise
# * Use a *while* loop to print the following text: 'Romanes eunt domus' a hundred times.

# %% [markdown]
# ## Exercise
# * Use a *while* loop and the exponentiation operator (see day 1) to print the following pattern:
#
# 1
#
# 10
#
# 100
#
# 1000
#
# 10000
#
# 100000

# %% [markdown]
# ## Exercise
# * Write a while loop in which the user is asked 10 times for input (number)
# * Print the sum of all entered numbers
