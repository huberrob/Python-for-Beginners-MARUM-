# %% [markdown]
# # Working with Pandas

# %% [markdown]
# ## Exercise
# * import pandas using:
# ** import pandas as pd
# * Create a dictionary which has two named lists as entries: one for Age and one for Temperature e.g. mydict ={'age':[1,2,3,4],'temp':....}. Both, age and temperature lists should contain about 10 values
# * Create a pandas dataframe (e.g. df = pd.DataFrame(mydict))using the list you just created
# * Print the dataframe
# * Using the .head() method, show the first 3 entries
# * Show the last entry using the .tail() method
# * print the column names
# * Call the .info() method

# %% [markdown]
# ## Exercise
# * use pd.read_csv to load data from the following file:
# ** https://raw.githubusercontent.com/huberrob/Python-for-Beginners-MARUM-/master/specmap.csv
# * print the columns
# * use pd.describe to get an overview of the data
# * use pd.shape to get the number of rows and columns
# * print the first 10 columns

# %% [markdown]
# ## Exercise
# * use the dataframe from the exercise above
# * show values of the age column only
# * show values from the row 5 to 15 of the temperature column

# %% [markdown]
# ## Exercise
# * Use the data frame again
# * use the describe method to get an overview statistics of the data
# * use the min, max, std, mean and median methods to calculate these statistics for the temperature column but for the first 20 rows only
