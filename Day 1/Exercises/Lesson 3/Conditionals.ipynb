# %% [markdown]
# # Conditionals

# %% [markdown]
# ## Exercise
# * Create two variables and assign number values to them
# * Write Python code which detects if variable 1 is greater than variable 2 and prints somethin useful

# %% [markdown]
# ## Exercise
# * Create two variables but assign string (text) values to them
# * Write some code to find out if both values are equal

# %% [markdown]
# ## Exercise
# * create a variable and assign a number value
# * write a condition which checks if the variable is greater than 2 or greater than 5 or greater than 10
# * also write a condition which checks if none of the above tests are true
# * print out the results

# %% [markdown]
# #Exercise
# * Create a variable called password and assign a string value to it.
# * use the input() method to read an user entered string and check if this equals the stored password

# %% [markdown]
# ## Exercise
# * Create two variables and assign a number to it
# * test if the first value is larger than the second one and if the first value is larger than zero
# * Print out  a useful result message
# * rewrite same routine so that you can use the input method to assign values to the variables

# %% [markdown]
# ## Exercise
# * Based on a Celsius value you receive from a user input calculate the Fahrenheit value (°F = °C * 1,8 + 32))
# * Print the Fahrenheit value

# %% [markdown]
# ## Exercise
# * Create two user input 'type' in which the user can enter 'C' or 'F'
# * Test if 'type' is either 'C' or 'F'
# * In case 'type' is 'C' calculate the Fahrenheit value
# * In case it id 'F' calculate the Celsius value : °C = (°F - 32) / 1.8
# * In case it is not C or F print an error message
# * Otherwise create an user input by which the user can enter the temperature value
# * Print out type, temperature of conversion calculations

# %% [markdown]
# ## Exercise
# * Create a user input variable
# * Write some python code which decides if the number is divisible by 7 (hint: use the modulo division operator)
# * Use type casting to convert input which is a string to number

# %% [markdown]
# ## Exercise
# * Let the user input two values a and b
# * Multiply the values and in case the result is larger than 100 also test if the result can be divided by 5
# * Do this in two steps. For each step print the result.
# * Use *else* to print something useful in case the condition is not true
