# %% [markdown]
# ## Transcript
# 1. Classes User defined
# 2. Creating and importing a module
# 3. Using methods of built-in classes (types)

# %% [markdown]
# # **Classes**

# %% [markdown]
# Python is an object oriented programming language.
#
# Almost everything in Python is an object, with its properties and methods.
#
# A Class is like an object constructor, or a "blueprint" for creating objects

# %% [markdown]
# ## Exercise 4a - user defined class<br>
# 1. Create a class named Vehicle, with a class variable (aka. attribute) named min_speed=5.
# 2. Create an object named bicycle1, and print the value of min_speed.

# %%
########################
#1.
########################

# created a class named Vehicle with the variable (aka attribute) min_speed
class Vehicle:
    min_speed=5

# %%
#######################
#2.
#######################

# creating an object of a class Vehicle
bicycle1=Vehicle()
# calling the variable 
bicycle1.min_speed
# Out:
# 5

# %% [markdown]
# Min_speed is a Vehicle class attribute. Class attributes belong to the class itself they will be shared by all the instances (objects). Such attributes are defined in the class body parts usually at the top.

# %% [markdown]
# # Exercise 4b
#
# 1. Update class named Vehicle, use the __init__() function to assign three variables (n_wheels, max_speed, and color) to hold values for number of wheels,maximum speed and color respectively.
# 2. Create an object named bicycle2 and print the value of number of wheels,maximum speed and color as follows:
# n_wheels = 2
# max_speed = 15
# color = 'red'
# 3. Add two functions inside a Vehicle class - **run_slowly**(prints out the minimum speed, see class variable '**min_speed**'),**run_fast** (prints out the maximum speed, see variable '**max_speed**'). Try callinng these methods using bicycle2 object. If this doesn't work create an object bicycle3 using the latest version of the Vehicle class. Then try to call the run_fast,fun_slowly methods.
# 5. apply type() function on bicycle3 object.

# %%
########################
#3.
########################

# created a class named Vehicle with the attribute min_speed
class Vehicle:
    min_speed=5
    
    def __init__(.....):
        self.n_wheels=....
  

# created an instance of the class Vehicle
# provided 3 arguments for __init__ function if the class
bicycle2 = ....
# lets call the provided values
print("number of wheels={},maximum speed={},Vehicle color={}".
      format(bicycle2.n_wheels,bicycle2.max_speed,bicycle2.color))
# Out:
# number of wheels=2,maximum speed=15,Vehicle color=red

# %%
######################
#4.
######################

class Vehicle:
    min_speed=5
    def __init__():
    
    def run_slowly(self):
        print("I'm riding {} km/h".format(self.min_speed))

# %%
# trying to call this method using bicycle2 object.
bicycle2.run_slowly
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-3a7124c92cca> in <module>()
#       1 # trying to call this method using bicycle2 object.
# ----> 2 bicycle2.run_slowly
#
# AttributeError: 'Vehicle' object has no attribute 'run_slowly'

# %% [markdown]
# We received an attribute error because object bicycle2 was initialized using previous version of Vehicle class where there haven't been methods "run_slowly" and "run_fast" yet.

# %%
# lets create a new object of the updated class Vehicle
bicycle3=Vehicle(2,15,"blue")
# call the methods "run_fast","run slowly" using this object
.....
# Out:
# I'm riding 15 km/h
# I'm riding 5 km/h

# %% [markdown]
# Now class methods are executed correctly.

# %%
############
#apply type() function on bicycle3 object.
############
......

# %% [markdown]
# # **Creating and importing a module**
# Modules refer to a file containing Python statements and definitions.
# We can define our most used functions in a module and import it, instead of copying their definitions into different programs.<br>
# There are 3 ways to import a file:
# 1. import somefile <br>
# Everything in somefile.py gets imported.
# To refer to something in the file, append the
# text “somefile.” to the front of its name.
# 2. from somefile import * <br>
# Everything in somefile.py gets imported. To refer to anything in the module, just use its
# name. Everything in the module is now in the
# current namespace.
# 3. from somefile import className <br>
# Only the item className in somefile.py gets
# imported.
# After importing className, you can just use it
# without a module prefix. It’s brought into the
# current namespace.
# Take care! Overwrites the definition of this
# name if already defined in the current
# namespace!

# %% [markdown]
# ## Exercise 4c<br>
# 1. Create a python module by creating "My_module.py" file in the current notebook directory. Insert the uncommnted code below in this .py file.
# 2. Try creating an object of the Person class providing name and age. Why didn't this work?
# 3. Now import the simple_module.py and repeat the 2. Try using all three previously mentioned methods of import of a class.
# 4. Call myfunc method of the person object.
# 5. Call get_square function.

# %%
##########
#2.
##########
person1=Person("Peter",19)

# %% [markdown]
# NameError caused by the abscence of the Person class name in current Nmaespace of our jupyter notebook.

# %%
##########
#3.
##########

import ....

# used module's name to refer to the class Person inside it
# created p1 - instance of the Person class, name = Peter, age = 19
p1=....
# call function 'greetings' using this p1 instance
....
# call 'get_square' function directly (without creating an instance)
....

# %%
#import only Person class from the module
from My_module import Person

# created another instance of Person class, without using a module prefix
p2=Person("Kevin",23)
p2.myfunc()
# but get_square function was not imported
get_square(4)

# %%
#import everything from My_module file
from My_module import *

# created another instance of Person class, without using a module prefix
p2=Person("Kevin",23)
p2.myfunc()

# can also directly use get_square function
get_square(4)
